# %%
#   1. Problem Definition   2. Dataset Exploration   3. Feature and Target Identification   4. Data Preparation 
# Page 5 of 6 
# •  5. Train/Test Split   6. Linear Regression Model   7. Predictions   8. Coefficients and Intercept 
# ML Lab Manual — Lab 5: Linear Regression (House Prices) 
# •  9. Residual Analysis   10. Regression Metrics   11. Training vs Testing Performance   12. Model Interpretation   
# 13. Conclusion
